# %% [markdown]
# # Lab 1 - Programming Foundation Exercises
# **Week 1 / Day1**
#
# - Student: **Andreas Papachristophorou**
# - Course: **AI Consulting & Integration 2026-06**
# - Date: **2026-06-27**

# %% [markdown]
# **Scenario:** You've been hired by a startup company called HomeGuard to develop a prototype for their smart home monitoring system. The system uses various sensors throughout a house to detect potential security issues, comfort problems, and equipment failures. Your job is to create a simulator that processes sensor readings and triggers appropriate alerts.

# %%
# HomeGuard Security System Simulator
# Author: Andreas Papachristophorou
# Description: Simulates smart home sensors and triggers alerts

# %% [markdown]
# ## Step 2: Creating Data Structures

# %% [markdown]
# **Sensors Dictionary:**
# - id: sensoor unique id eg. S1, S2, S3 ....
# - location: room, door etc eg. Living Room, Bedroom1, Main Door, etc
# - type: Motion, Temperature, Door, Smoke
# - current_value: 0 (inactive), 1 (active),

# %%
# Importing nesseary libraries
import random # to generate random sensor values for testing
import datetime # to get the current date and time for alerts

# %%
# Creates a dictionary for each sensor with its id, location, type, and current value
def create_sensor(sensor_id, location, sensor_type, initial_value=None):
    sensor = {
        "id": sensor_id,
        "location": location,
        "type": sensor_type,
        "current_value": initial_value,
    }
    return sensor

# %%
# Initializes a list of sensors with their respective attributes
def initialize_sensors():
    sensors = []
    sensors.append(create_sensor("S1", "Front_Door", "door"))
    sensors.append(create_sensor("S2", "Living_Room", "motion"))
    sensors.append(create_sensor("S3", "Living_Room", "temperature"))
    sensors.append(create_sensor("S4", "Living_Room", "smoke"))
    return sensors

# %%
# Output the list of sensors and their types
for sensors in initialize_sensors():
    print("Sensor ID:", sensors['id'], "Type:", sensors['type'], "Location:", sensors['location'], "Current Value:", sensors['current_value'])
# Out:
# Sensor ID: S1 Type: door Location: Front_Door Current Value: None
# Sensor ID: S2 Type: motion Location: Living_Room Current Value: None
# Sensor ID: S3 Type: temperature Location: Living_Room Current Value: None
# Sensor ID: S4 Type: smoke Location: Living_Room Current Value: None

# %% [markdown]
# **Alert dictionary might have:**
# - "sensor_id"
# - "alert_value": current value form sensor at the time or the alert
# - "alert_type": e.g., "SECURITY", "COMFORT", "EQUIPMENT"
# - "message": human-readable description e.g. motion detected, smoke detected, high temp, low temp
# - "timestamp": date and time of the alert

# %%
# Creates a dictionary for each alert with its sensor id, alert value, alert type, message, and timestamp
def create_alert(sensor_id, alert_value, alert_type, alert_severity, message, timestamp):
    alert = {
        "sensor_id": sensor_id,
        "alert_value": alert_value,
        "alert_type": alert_type, # determines the type of alert based on sensor type and value
        "severity": alert_severity, # determines the severity based on alert type and value
        "message": message,
        "timestamp": timestamp,
    }
    return alert

# %%
# Creates a list of alerts and appends a new alert to the list
def update_alerts(alerts_list, alert):
    alerts_list.append(alert)
    return alerts_list

# %% [markdown]
# **System State Dictionary**
# - "mode": "home" or "away"
# - "alerts": list of current alerts?
# - "sensors": list of sensor dictionaries?

# %%
# function that intializes the system state with the given mode, sensors, event log, and alerts list
def initialize_system_state(mode):
    state = {
        "mode": mode,
        "sensors": initialize_sensors(),
        "event_log": [],
        "alerts_list": []
    }
    return state

# %%
# Setting he event log and alerts list to the initialized system state
state = initialize_system_state("HOME")
event_log = state["event_log"]
alerts_list = state["alerts_list"]

# %% [markdown]
# ## Step 3: Implementing If/Else Logic
# Do: Write conditional statements to check sensor thresholds and system modes.

# %%
# Check if the sensor value is true and return alert if it does. If the sensor value is not true, return False.
# This is used for door sensors, which have a boolean value of True or False.
def check_sensor_door(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor['id']} at {sensor['location']}")
    if sensor['current_value']: # check if the sensor value is True.
        current_time = datetime.datetime.now() # get the current date and time for the alert
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S") # format the timestamp
        print(f"Alert: Sensor {sensor['id']} at {sensor['location']} indicates a door opening! High risk of intrusion. timestamp: {timestamp}")
        new_alert = create_alert(sensor['id'], sensor['current_value'], "SECURITY",  "HIGH", "Opened door", timestamp)
        update_alerts(alerts_list, new_alert) # updated the alerts list with the new alert
        return new_alert
    
    return False # check if the sensor value is False

# %%
# Check if the sensor value is true and return alert if it does. If the sensor value is not true, return False.
# This is used for motion sensors, which have a boolean value of True or False.
def check_sensor_motion(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor['id']} at {sensor['location']}")
    if sensor['current_value']: # check if the sensor value is True.
        current_time = datetime.datetime.now() # get the current date and time for the alert
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S") # format the timestamp
        print(f"Alert: Sensor {sensor['id']} at {sensor['location']} detected movement. High risk of intrusion. timestamp: {timestamp}")
        new_alert = create_alert(sensor['id'], sensor['current_value'], "SECURITY",  "HIGH", "Motion detected", timestamp)
        update_alerts(alerts_list, new_alert) # updated the alerts list with the new alert
        return new_alert
    
    return False # check if the sensor value is False

# %%
# Check if the sensor value matches the expected value and return alert if it does.
# If the sensor value does not match the expected value, return False.
# This is used for smoke sensors, which have a boolean value of True or False.
def check_sensor_smoke(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor['id']} at {sensor['location']}")
    if sensor['current_value']:  # check if the sensor value is True.
        current_time = datetime.datetime.now()  # get the current date and time for the alert
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")  # format the timestamp
        print(f"Alert: Sensor {sensor['id']} at {sensor['location']} detected smoke. High risk of fire. timestamp: {timestamp}")
        new_alert = create_alert(sensor['id'], sensor['current_value'], "SAFETY", "HIGH", "Smoke detected", timestamp)
        update_alerts(alerts_list, new_alert)  # update the alerts list with the new alert
        return new_alert

    return False  # check if the sensor value is False

# %%
# Check if the sensor value is above or below the expected value and return alert if it does. If the sensor value is within the expected range, return False.
# This is used for temperature sensors, which have a numeric value.
# This only for equipment failure and frozen pipe risk. The expected range is between 35 and 95 degrees Fahrenheit.
def check_sensor_temperature(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor['id']} at {sensor['location']}")
    if sensor['current_value'] > 95: # check if the sensor value is above 95 (for temperature sensors) and return an alert if it is
        current_time = datetime.datetime.now()  # get the current date and time for the alert
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")  # format the timestamp
        print(f"Alert: Sensor {sensor['id']} at {sensor['location']} has triggered a high temperature alert!"
              f"Current value: {sensor['current_value']} °F, Equipment failure risk. timestamp: {timestamp}")
        new_alert = create_alert(sensor['id'], sensor['current_value'], "SAFETY", "MEDIUM", "High temperature", timestamp)
        update_alerts(alerts_list, new_alert)  # update the alerts list with the new alert
        return new_alert
    
    elif sensor['current_value'] < 35: # check if the sensor value is below 35 (for temperature sensors) and return an alert if it is
        current_time = datetime.datetime.now()  # get the current date and time for the alert
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")  # format the timestamp
        print(f"Alert: Sensor {sensor['id']} at {sensor['location']} has triggered a low temperature alert!"
              f"Current value: {sensor['current_value']} °F, Frozen pipe risk. timestamp: {timestamp}")
        new_alert = create_alert(sensor['id'], sensor['current_value'], "SAFETY", "MEDIUM", "Low temperature", timestamp)
        update_alerts(alerts_list, new_alert)  # update the alerts list with the new alert
        return new_alert
    
    return False

# %%
# Check if the temperature is outside the comfort range in HOME mode.
# If it is outside 65-75°F, create and return a comfort notification.
# If it is within range, return False.
def check_home_comfort_temperature(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor['id']} at {sensor['location']}")
    if sensor['current_value'] < 65:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")
        print(f"Notification: Sensor {sensor['id']} at {sensor['location']} reports a low comfort temperature. "
            f"Current value: {sensor['current_value']} °F. Home may feel too cold. timestamp: {timestamp}")
        new_alert = create_alert(sensor['id'], sensor['current_value'], "COMFORT", "LOW","Temperature below comfort range", timestamp)
        update_alerts(alerts_list, new_alert)
        return new_alert

    elif sensor['current_value'] > 75:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")
        print(f"Notification: Sensor {sensor['id']} at {sensor['location']} reports a high comfort temperature. "
              f"Current value: {sensor['current_value']} °F. Home may feel too warm. timestamp: {timestamp}")
        new_alert = create_alert(sensor['id'], sensor['current_value'], "COMFORT", "LOW", "Temperature above comfort range", timestamp)
        update_alerts(alerts_list, new_alert)
        return new_alert

    return False

# %%
# Check if a door has been left open for more than 5 minutes in HOME mode.
# If it has, create and return a reminder notification.
# If not, return False.
def check_door_left_open(sensor, alerts_list, event_log):
    sensor.setdefault('opened_at', None) # Ensure 'opened_at' key exists in the sensor dictionary
    log_event(event_log, f"Checking sensor {sensor['id']} at {sensor['location']}")

    if sensor['current_value'] is True:
        if sensor['opened_at'] is None:
            sensor['opened_at'] = datetime.datetime.now()

        current_time = datetime.datetime.now() # reads the current time
        time_open = current_time - sensor['opened_at'] # calculates the time the door has been open
        minutes_open = time_open.total_seconds() / 60

        if minutes_open > 5: # if the door has been open for more than 5 minutes, create a reminder notification
            timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")
            print(f"Reminder: Sensor {sensor['id']} at {sensor['location']} has been left open for more than 5 minutes."
                  f"Current open time: {int(minutes_open)} minutes. timestamp: {timestamp}")
            new_alert = create_alert(sensor['id'], sensor['current_value'],"COMFORT", "LOW","Door left open", timestamp)
            update_alerts(alerts_list, new_alert)
            return new_alert

    else:
        sensor['opened_at'] = None

    return False

# %%
# Process sensor readings based on the current system mode and trigger appropriate alerts or notifications
def process_sensor_by_mode(sensor, alerts_list, event_log, system_mode):
    sensor_type = sensor['type'].lower()

    if system_mode == "AWAY":
        if sensor_type == "door":
            return check_sensor_door(sensor, alerts_list, event_log)
        elif sensor_type == "motion":
            return check_sensor_motion(sensor, alerts_list, event_log)
        elif sensor_type == "smoke":
            return check_sensor_smoke(sensor, alerts_list, event_log)
        elif sensor_type == "temperature":
            return check_sensor_temperature(sensor, alerts_list, event_log)

    elif system_mode == "HOME":
        if sensor_type == "door":
            return check_door_left_open(sensor, alerts_list, event_log)
        elif sensor_type == "smoke":
            return check_sensor_smoke(sensor, alerts_list, event_log)
        elif sensor_type == "temperature":
            danger_alert = check_sensor_temperature(sensor, alerts_list, event_log)
            if danger_alert:
                return danger_alert
            return check_home_comfort_temperature(sensor, alerts_list, event_log)

    return False

# %% [markdown]
# ## Step 4: Building Functions
# Do: Create functions to generate sensor readings, process them, trigger alerts, and log events.

# %%
# Logs events with a timestamp and message to the event log list
def log_event(event_log, message):
    current_time = datetime.datetime.now()
    timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")
    event_log.append(f"{timestamp} - {message}")
    return event_log

# %%
# Generates a sensor reading that triggers an alert for demonstration purposes
def generate_sensor_reading(sensor):
    sensor_type = sensor['type'].lower()

    if sensor_type == "door":
        sensor['current_value'] = random.choice([True, False])

    elif sensor_type == "motion":
        sensor['current_value'] = random.choice([True, False])

    elif sensor_type == "smoke":
        sensor['current_value'] = random.choice([True, False])

    elif sensor_type == "temperature":
        sensor['current_value'] = round(random.uniform(30, 100), 1)

    return sensor

# %%
# Processes all sensors in the list, generates readings, logs events, and checks for alerts based on the current system mode
def process_all_sensors(sensors, alerts_list, event_log, system_mode):
    for sensor in sensors:
        generate_sensor_reading(sensor) # genrates a new random reading for the sensor
        log_event(event_log, f"Sensor {sensor['id']} at {sensor['location']} generated reading: {sensor['current_value']}") # log the event
        process_sensor_by_mode(sensor, alerts_list, event_log, system_mode) # process each accordign to system mode and sensor type

# %%
# Function to get the system mode from the user
def get_system_mode():
    while True:
        mode = input("Welcome to HomeGuard! Enter mode (HOME or AWAY): ").upper()
        if mode == "HOME" or mode == "AWAY":
            log_event(event_log, f"System mode set to {mode}")
            return mode
        print("Invalid mode. Please enter HOME or AWAY.")
        log_event(event_log, "Invalid system mode entered.")

# %%
system_mode = get_system_mode() # sets the system mode to the user input and logs the event
print("System mode is:", system_mode)
# Out:
# System mode is: AWAY

# %%
# Initialize sensors and process them based on the current system mode
sensors = initialize_sensors()

process_all_sensors(sensors, alerts_list, event_log, system_mode)
# Out:
# Alert: Sensor S2 at Living_Room detected movement. High risk of intrusion. timestamp: 2026-07-09 22:06:15
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-09 22:06:15

# %%
for alert in alerts_list: # prints all the alerts that have been triggered during the simulation
    print("Alert:", alert)
# Out:
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:52:22'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:52:22'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:53:34'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:53:34'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:53:53'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:53:53'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:56:00'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:56:04'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:56:06'}
# Alert: {'sensor_id': 'S2', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Motion detected', 'timestamp': '2026-07-09 21:56:06'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:56:06'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:59:37'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:59:37'}
# Alert: {'sensor_id': 'S3', 'alert_value': 98.2, 'alert_type': 'SAFETY', 'severity': 'MEDIUM', 'message': 'High temperature', 'timestamp': '2026-07-09 21:59:45'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:59:45'}
# Alert: {'sensor_id': 'S2', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Motion detected', 'timestamp': '2026-07-09 21:59:47'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:59:48'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:59:49'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:59:52'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 21:59:56'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 21:59:58'}
# Alert: {'sensor_id': 'S3', 'alert_value': 98.3, 'alert_type': 'SAFETY', 'severity': 'MEDIUM', 'message': 'High temperature', 'timestamp': '2026-07-09 22:00:01'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 22:00:01'}
# Alert: {'sensor_id': 'S2', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Motion detected', 'timestamp': '2026-07-09 22:05:38'}
# Alert: {'sensor_id': 'S1', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Opened door', 'timestamp': '2026-07-09 22:05:39'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 22:05:41'}
# Alert: {'sensor_id': 'S2', 'alert_value': True, 'alert_type': 'SECURITY', 'severity': 'HIGH', 'message': 'Motion detected', 'timestamp': '2026-07-09 22:06:15'}
# Alert: {'sensor_id': 'S4', 'alert_value': True, 'alert_type': 'SAFETY', 'severity': 'HIGH', 'message': 'Smoke detected', 'timestamp': '2026-07-09 22:06:15'}

# %%
event_log # prints all the events that have been logged during the simulation
# Out:
# ['2026-07-09 21:51:49 - System mode set to AWAY',
#  '2026-07-09 21:51:49 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 21:51:49 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:51:49 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:51:49 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:51:49 - Sensor S3 at Living_Room generated reading: 62.3',
#  '2026-07-09 21:51:49 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:51:49 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 21:51:49 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:52:22 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:52:22 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:52:22 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:52:22 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:52:22 - Sensor S3 at Living_Room generated reading: 55.4',
#  '2026-07-09 21:52:22 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:52:22 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:52:22 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:53:34 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:53:34 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:53:34 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:53:34 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:53:34 - Sensor S3 at Living_Room generated reading: 77.9',
#  '2026-07-09 21:53:34 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:53:34 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:53:34 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:53:53 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:53:53 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:53:53 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:53:53 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:53:53 - Sensor S3 at Living_Room generated reading: 74.2',
#  '2026-07-09 21:53:53 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:53:53 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:53:53 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:56:00 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:56:00 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:56:00 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:56:00 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:56:00 - Sensor S3 at Living_Room generated reading: 94.9',
#  '2026-07-09 21:56:00 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:56:00 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 21:56:00 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:56:04 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:56:04 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:56:04 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:56:04 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:56:04 - Sensor S3 at Living_Room generated reading: 52.8',
#  '2026-07-09 21:56:04 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:56:04 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 21:56:04 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:56:06 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:56:06 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:56:06 - Sensor S2 at Living_Room generated reading: True',
#  '2026-07-09 21:56:06 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:56:06 - Sensor S3 at Living_Room generated reading: 74.9',
#  '2026-07-09 21:56:06 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:56:06 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:56:06 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:37 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:59:37 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:37 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:37 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:37 - Sensor S3 at Living_Room generated reading: 89.9',
#  '2026-07-09 21:59:37 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:37 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:59:37 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:45 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 21:59:45 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:45 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:45 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:45 - Sensor S3 at Living_Room generated reading: 98.2',
#  '2026-07-09 21:59:45 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:45 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:59:45 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:47 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 21:59:47 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:47 - Sensor S2 at Living_Room generated reading: True',
#  '2026-07-09 21:59:47 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:47 - Sensor S3 at Living_Room generated reading: 47.6',
#  '2026-07-09 21:59:47 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:47 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 21:59:47 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:48 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 21:59:48 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:48 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:48 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:48 - Sensor S3 at Living_Room generated reading: 83.1',
#  '2026-07-09 21:59:48 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:48 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:59:48 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:49 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 21:59:49 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:49 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:49 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:49 - Sensor S3 at Living_Room generated reading: 68.2',
#  '2026-07-09 21:59:49 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:49 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:59:49 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:50 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 21:59:50 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:50 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:50 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:50 - Sensor S3 at Living_Room generated reading: 68.9',
#  '2026-07-09 21:59:50 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:50 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 21:59:50 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:52 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:59:52 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:52 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:52 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:52 - Sensor S3 at Living_Room generated reading: 73.1',
#  '2026-07-09 21:59:52 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:52 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 21:59:52 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:56 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 21:59:56 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:56 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:56 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:56 - Sensor S3 at Living_Room generated reading: 66.8',
#  '2026-07-09 21:59:56 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:56 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 21:59:56 - Checking sensor S4 at Living_Room',
#  '2026-07-09 21:59:58 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 21:59:58 - Checking sensor S1 at Front_Door',
#  '2026-07-09 21:59:58 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 21:59:58 - Checking sensor S2 at Living_Room',
#  '2026-07-09 21:59:58 - Sensor S3 at Living_Room generated reading: 69.5',
#  '2026-07-09 21:59:58 - Checking sensor S3 at Living_Room',
#  '2026-07-09 21:59:58 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 21:59:58 - Checking sensor S4 at Living_Room',
#  '2026-07-09 22:00:01 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 22:00:01 - Checking sensor S1 at Front_Door',
#  '2026-07-09 22:00:01 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 22:00:01 - Checking sensor S2 at Living_Room',
#  '2026-07-09 22:00:01 - Sensor S3 at Living_Room generated reading: 98.3',
#  '2026-07-09 22:00:01 - Checking sensor S3 at Living_Room',
#  '2026-07-09 22:00:01 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 22:00:01 - Checking sensor S4 at Living_Room',
#  '2026-07-09 22:05:38 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 22:05:38 - Checking sensor S1 at Front_Door',
#  '2026-07-09 22:05:38 - Sensor S2 at Living_Room generated reading: True',
#  '2026-07-09 22:05:38 - Checking sensor S2 at Living_Room',
#  '2026-07-09 22:05:38 - Sensor S3 at Living_Room generated reading: 38.4',
#  '2026-07-09 22:05:38 - Checking sensor S3 at Living_Room',
#  '2026-07-09 22:05:38 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 22:05:38 - Checking sensor S4 at Living_Room',
#  '2026-07-09 22:05:39 - Sensor S1 at Front_Door generated reading: True',
#  '2026-07-09 22:05:39 - Checking sensor S1 at Front_Door',
#  '2026-07-09 22:05:39 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 22:05:39 - Checking sensor S2 at Living_Room',
#  '2026-07-09 22:05:39 - Sensor S3 at Living_Room generated reading: 43.8',
#  '2026-07-09 22:05:39 - Checking sensor S3 at Living_Room',
#  '2026-07-09 22:05:39 - Sensor S4 at Living_Room generated reading: False',
#  '2026-07-09 22:05:39 - Checking sensor S4 at Living_Room',
#  '2026-07-09 22:05:41 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 22:05:41 - Checking sensor S1 at Front_Door',
#  '2026-07-09 22:05:41 - Sensor S2 at Living_Room generated reading: False',
#  '2026-07-09 22:05:41 - Checking sensor S2 at Living_Room',
#  '2026-07-09 22:05:41 - Sensor S3 at Living_Room generated reading: 39.7',
#  '2026-07-09 22:05:41 - Checking sensor S3 at Living_Room',
#  '2026-07-09 22:05:41 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 22:05:41 - Checking sensor S4 at Living_Room',
#  '2026-07-09 22:06:15 - Sensor S1 at Front_Door generated reading: False',
#  '2026-07-09 22:06:15 - Checking sensor S1 at Front_Door',
#  '2026-07-09 22:06:15 - Sensor S2 at Living_Room generated reading: True',
#  '2026-07-09 22:06:15 - Checking sensor S2 at Living_Room',
#  '2026-07-09 22:06:15 - Sensor S3 at Living_Room generated reading: 66.2',
#  '2026-07-09 22:06:15 - Checking sensor S3 at Living_Room',
#  '2026-07-09 22:06:15 - Sensor S4 at Living_Room generated reading: True',
#  '2026-07-09 22:06:15 - Checking sensor S4 at Living_Room']

# %% [markdown]
# ## Step 5: Creating Classes
# Do: Convert the sensor dictionary into a Sensor class with methods.

# %%
class Sensor:
    def __init__(self, sensor_id, location, sensor_type, initial_value=None):
        self.id = sensor_id
        self.location = location
        self.type = sensor_type.lower()
        self.current_value = initial_value
        self.opened_at = None

    def read(self):
        if self.type == "door":
            self.current_value = random.choice([True, False])
        elif self.type == "motion":
            self.current_value = random.choice([True, False])
        elif self.type == "smoke":
            self.current_value = random.choice([True, False])
        elif self.type == "temperature":
            self.current_value = round(random.uniform(30, 100), 1)
        return self.current_value

    def isAbnormal(self):
        if self.type == "door":
            return self.current_value is True
        elif self.type == "motion":
            return self.current_value is True
        elif self.type == "smoke":
            return self.current_value is True
        elif self.type == "temperature":
            return self.current_value > 75 or self.current_value < 65

        return False

    def reset(self):
        self.current_value = None
        self.opened_at = None

# %%
def initialize_sensors():
    sensors = []
    sensors.append(Sensor("S1", "FrontDoor", "door"))
    sensors.append(Sensor("S2", "LivingRoom", "motion"))
    sensors.append(Sensor("S3", "LivingRoom", "temperature"))
    sensors.append(Sensor("S4", "LivingRoom", "smoke"))
    return sensors

# %%
print("Sensors initialized:")
for sensor in initialize_sensors():
    print(f"Sensor ID: {sensor.id}, Type: {sensor.type}, Location: {sensor.location}, Current Value: {sensor.current_value}")
# Out:
# Sensors initialized:
# Sensor ID: S1, Type: door, Location: FrontDoor, Current Value: None
# Sensor ID: S2, Type: motion, Location: LivingRoom, Current Value: None
# Sensor ID: S3, Type: temperature, Location: LivingRoom, Current Value: None
# Sensor ID: S4, Type: smoke, Location: LivingRoom, Current Value: None

# %%
# Verify that I have a Sensor class and can create sensor objects.
sensor1 = Sensor("S1", "Front_Door", "door")

print(type(sensor1))
print(sensor1.id)
print(sensor1.location)
print(sensor1.type)
print(sensor1.current_value)
print(sensor1.opened_at)
# Out:
# <class '__main__.Sensor'>
# S1
# Front_Door
# door
# None
# None

# %% [markdown]
# ## Step 6: Integrating Everything
# Do: Combine all components into a complete simulator that runs continuously.

# %%
import random
import datetime
import time

# create a list of sensor objects as a class
class Sensor:
    def __init__(self, sensor_id, location, sensor_type, initial_value=None):
        self.id = sensor_id
        self.location = location
        self.type = sensor_type
        self.current_value = initial_value
        self.opened_at = None

    def read(self):
        sensor_type = self.type.lower()

        if sensor_type == "door":
            self.current_value = random.choice([True, False])
        elif sensor_type == "motion":
            self.current_value = random.choice([True, False])
        elif sensor_type == "smoke":
            self.current_value = random.choice([True, False])
        elif sensor_type == "temperature":
            self.current_value = round(random.uniform(30, 100), 1)
        return self.current_value

    def reset(self):
        self.current_value = None
        self.opened_at = None

    def isAbnormal(self):
        sensor_type = self.type.lower()
        if sensor_type in ["door", "motion", "smoke"]:
            return self.current_value is True
        elif sensor_type == "temperature":
            return self.current_value > 95 or self.current_value < 35
        return False

# %%
# Initialize a list of sensor objects with their respective attributes
def initialize_sensors():
    sensors = []
    sensors.append(Sensor("S1", "Front_Door", "door"))
    sensors.append(Sensor("S2", "Living_Room", "motion"))
    sensors.append(Sensor("S3", "Living_Room", "temperature"))
    sensors.append(Sensor("S4", "Living_Room", "smoke"))
    return sensors

# %%
# Creating an alert dictionary with sensor id, alert value, alert type, severity, message, and timestamp
def create_alert(sensor_id, alert_value, alert_type, alert_severity, message, timestamp):
    alert = {
        "sensor_id": sensor_id,
        "alert_value": alert_value,
        "alert_type": alert_type,
        "severity": alert_severity,
        "message": message,
        "timestamp": timestamp,
    }
    return alert

# Updates the alerts list by appending a new alert to it and returns the updated list
def update_alerts(alerts_list, alert):
    alerts_list.append(alert)
    return alerts_list

# Logs events with a timestamp and message to the event log list
def log_event(event_log, message):
    current_time = datetime.datetime.now()
    timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")
    event_log.append(f"{timestamp} - {message}")
    return event_log

# %%
# Changing the check sensor function to use the class objects instaed of the dictionary based ones.
# This will allow for better encapsulation and object-oriented design.

# Check if the door sensor is active and return an intrusion alert.
def check_sensor_door(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor.id} at {sensor.location}")

    if sensor.current_value:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")

        print(f"Alert: Sensor {sensor.id} at {sensor.location} indicates a door opening! High risk of intrusion. timestamp: {timestamp}")

        new_alert = create_alert(
            sensor.id,
            sensor.current_value,
            "SECURITY",
            "HIGH",
            "Opened door",
            timestamp
        )
        update_alerts(alerts_list, new_alert)
        return new_alert

    return False

# Check if the motion sensor is active and return an intrusion alert.
def check_sensor_motion(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor.id} at {sensor.location}")

    if sensor.current_value:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")

        print(f"Alert: Sensor {sensor.id} at {sensor.location} detected movement. High risk of intrusion. timestamp: {timestamp}")

        new_alert = create_alert(
            sensor.id,
            sensor.current_value,
            "SECURITY",
            "HIGH",
            "Motion detected",
            timestamp
        )
        update_alerts(alerts_list, new_alert)
        return new_alert

    return False

# Check if the smoke sensor is active and return a fire alert.
def check_sensor_smoke(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor.id} at {sensor.location}")

    if sensor.current_value:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")

        print(f"Alert: Sensor {sensor.id} at {sensor.location} detected smoke. High risk of fire. timestamp: {timestamp}")

        new_alert = create_alert(
            sensor.id,
            sensor.current_value,
            "SAFETY",
            "HIGH",
            "Smoke detected",
            timestamp
        )
        update_alerts(alerts_list, new_alert)
        return new_alert

    return False

# Check if the temperature is dangerously high or low.
def check_sensor_temperature(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor.id} at {sensor.location}")

    if sensor.current_value > 95:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")

        print(
            f"Alert: Sensor {sensor.id} at {sensor.location} has triggered a high temperature alert! "
            f"Current value: {sensor.current_value} °F, Equipment failure risk. timestamp: {timestamp}"
        )

        new_alert = create_alert(
            sensor.id,
            sensor.current_value,
            "SAFETY",
            "MEDIUM",
            "High temperature",
            timestamp
        )
        update_alerts(alerts_list, new_alert)
        return new_alert

    elif sensor.current_value < 35:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")

        print(
            f"Alert: Sensor {sensor.id} at {sensor.location} has triggered a low temperature alert! "
            f"Current value: {sensor.current_value} °F, Frozen pipe risk. timestamp: {timestamp}"
        )

        new_alert = create_alert(
            sensor.id,
            sensor.current_value,
            "SAFETY",
            "MEDIUM",
            "Low temperature",
            timestamp
        )
        update_alerts(alerts_list, new_alert)
        return new_alert

    return False

# Check if the temperature is outside the comfort range in HOME mode.
def check_home_comfort_temperature(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor.id} at {sensor.location}")

    if sensor.current_value < 65:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")

        print(
            f"Notification: Sensor {sensor.id} at {sensor.location} reports a low comfort temperature. "
            f"Current value: {sensor.current_value} °F. Home may feel too cold. timestamp: {timestamp}"
        )

        new_alert = create_alert(
            sensor.id,
            sensor.current_value,
            "COMFORT",
            "LOW",
            "Temperature below comfort range",
            timestamp
        )
        update_alerts(alerts_list, new_alert)
        return new_alert

    elif sensor.current_value > 75:
        current_time = datetime.datetime.now()
        timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")

        print(
            f"Notification: Sensor {sensor.id} at {sensor.location} reports a high comfort temperature. "
            f"Current value: {sensor.current_value} °F. Home may feel too warm. timestamp: {timestamp}"
        )

        new_alert = create_alert(
            sensor.id,
            sensor.current_value,
            "COMFORT",
            "LOW",
            "Temperature above comfort range",
            timestamp
        )
        update_alerts(alerts_list, new_alert)
        return new_alert

    return False

# Check if a door has been left open for more than 5 minutes in HOME mode and return a reminder notification.
def check_door_left_open(sensor, alerts_list, event_log):
    log_event(event_log, f"Checking sensor {sensor.id} at {sensor.location}")

    if sensor.current_value is True:
        if sensor.opened_at is None:
            sensor.opened_at = datetime.datetime.now()

        current_time = datetime.datetime.now()
        time_open = current_time - sensor.opened_at
        minutes_open = time_open.total_seconds() / 60

        if minutes_open > 5:
            timestamp = current_time.strftime("%Y-%m-%d %H:%M:%S")
            print(f"Reminder: Sensor {sensor.id} at {sensor.location} has been left open for more than 5 minutes. Current open time: {int(minutes_open)} minutes. timestamp: {timestamp}")

            new_alert = create_alert(sensor.id, sensor.current_value, "COMFORT", "LOW", "Door left open", timestamp)
            update_alerts(alerts_list, new_alert)
            return new_alert
    else:
        sensor.opened_at = None

    return False

# %%
# Processing all sensors according to the system mode and triggering appropriate alerts or notifications
def process_sensor_by_mode(sensor, alerts_list, event_log, system_mode):
    sensor_type = sensor.type.lower()

    if system_mode == "AWAY":
        if sensor_type == "door":
            return check_sensor_door(sensor, alerts_list, event_log)
        elif sensor_type == "motion":
            return check_sensor_motion(sensor, alerts_list, event_log)
        elif sensor_type == "smoke":
            return check_sensor_smoke(sensor, alerts_list, event_log)
        elif sensor_type == "temperature":
            return check_sensor_temperature(sensor, alerts_list, event_log)

    elif system_mode == "HOME":
        if sensor_type == "door":
            return check_door_left_open(sensor, alerts_list, event_log)
        elif sensor_type == "smoke":
            return check_sensor_smoke(sensor, alerts_list, event_log)
        elif sensor_type == "temperature":
            danger_alert = check_sensor_temperature(sensor, alerts_list, event_log)
            if danger_alert:
                return danger_alert

            return check_home_comfort_temperature(sensor, alerts_list, event_log)

    return False

# %%
# Reading all sensors, logging events, and processing them based on the current system mode
def process_all_sensors(sensors, alerts_list, event_log, system_mode):
    for sensor in sensors:
        sensor.read()
        log_event(event_log, f"Sensor {sensor.id} at {sensor.location} generated reading: {sensor.current_value}")
        process_sensor_by_mode(sensor, alerts_list, event_log, system_mode)

# %%
def get_system_mode():
    while True:
        mode = input("Welcome to HomeGuard! Enter mode (HOME or AWAY): ").upper()
        if mode == "HOME" or mode == "AWAY":
            return mode
        print("Invalid mode. Please enter HOME or AWAY.")

# %%
def display_sensor_readings(sensors):
    print("\nCurrent Sensor Readings:")
    print("-" * 50)
    for sensor in sensors:
        print(f"Sensor ID: {sensor.id} | Type: {sensor.type} | Location: {sensor.location} | Value: {sensor.current_value}")

# %%
def display_alerts(alerts_list, start_index):
    new_alerts = alerts_list[start_index:]

    if new_alerts:
        print("\nNew Alerts:")
        print("-" * 50)
        for alert in new_alerts:
            print(f"[{alert['timestamp']}] {alert['alert_type']} - {alert['message']} "
                  f"(Sensor {alert['sensor_id']}, Severity: {alert['severity']}, Value: {alert['alert_value']})")
    else:
        print("\nNew Alerts:")
        print("-" * 50)
        print("No new alerts this cycle.")

# %%
def run_simulator():
    system_mode = get_system_mode()
    state = initialize_system_state(system_mode)

    sensors = state["sensors"]
    alerts_list = state["alerts_list"]
    event_log = state["event_log"]

    log_event(event_log, f"System mode set to {system_mode}")

    print("\nHomeGuard Simulator Started")
    print("=" * 50)
    print(f"System Mode: {system_mode}")

    cycle = 1

    while True:
        print(f"\nSimulation Cycle #{cycle}")
        print("=" * 50)

        old_alert_count = len(alerts_list)

        process_all_sensors(sensors, alerts_list, event_log, system_mode)
        display_sensor_readings(sensors)
        display_alerts(alerts_list, old_alert_count)

        user_choice = input("\nPress Enter to continue, type CHANGE to switch mode, or type STOP to end: ").upper()

        if user_choice == "STOP":
            print("\nSimulator stopped.")
            break

        elif user_choice == "CHANGE":
            system_mode = get_system_mode()
            state["mode"] = system_mode
            log_event(event_log, f"System mode changed to {system_mode}")
            print(f"\nSystem mode changed to {system_mode}")

        cycle += 1

    print("\nFinal Event Log:")
    print("-" * 50)
    for event in event_log:
        print(event)

# %%
run_simulator()
# Out:
# HomeGuard Simulator Started
# ==================================================
# System Mode: AWAY
#
# Simulation Cycle #1
# ==================================================
# Alert: Sensor S2 at Living_Room detected movement. High risk of intrusion. timestamp: 2026-07-09 23:50:56
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-09 23:50:56
#
# Current Sensor Readings:
# --------------------------------------------------
# Sensor ID: S1 | Type: door | Location: Front_Door | Value: False
# Sensor ID: S2 | Type: motion | Location: Living_Room | Value: True
# Sensor ID: S3 | Type: temperature | Location: Living_Room | Value: 88.3
# Sensor ID: S4 | Type: smoke | Location: Living_Room | Value: True
#
# New Alerts:
# --------------------------------------------------
# [2026-07-09 23:50:56] SECURITY - Motion detected (Sensor S2, Severity: HIGH, Value: True)
# [2026-07-09 23:50:56] SAFETY - Smoke detected (Sensor S4, Severity: HIGH, Value: True)
#
# Simulation Cycle #2
# ==================================================
# Alert: Sensor S1 at Front_Door indicates a door opening! High risk of intrusion. timestamp: 2026-07-09 23:52:10
# Alert: Sensor S2 at Living_Room detected movement. High risk of intrusion. timestamp: 2026-07-09 23:52:10
# Alert: Sensor S3 at Living_Room has triggered a high temperature alert! Current value: 96.2 °F, Equipment failure risk. timestamp: 2026-07-09 23:52:10
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-09 23:52:10
#
# Current Sensor Readings:
# --------------------------------------------------
# Sensor ID: S1 | Type: door | Location: Front_Door | Value: True
# Sensor ID: S2 | Type: motion | Location: Living_Room | Value: True
# Sensor ID: S3 | Type: temperature | Location: Living_Room | Value: 96.2
# Sensor ID: S4 | Type: smoke | Location: Living_Room | Value: True
#
# New Alerts:
# --------------------------------------------------
# [2026-07-09 23:52:10] SECURITY - Opened door (Sensor S1, Severity: HIGH, Value: True)
# [2026-07-09 23:52:10] SECURITY - Motion detected (Sensor S2, Severity: HIGH, Value: True)
# [2026-07-09 23:52:10] SAFETY - High temperature (Sensor S3, Severity: MEDIUM, Value: 96.2)
# [2026-07-09 23:52:10] SAFETY - Smoke detected (Sensor S4, Severity: HIGH, Value: True)
#
# Simulation Cycle #3
# ==================================================
# Alert: Sensor S1 at Front_Door indicates a door opening! High risk of intrusion. timestamp: 2026-07-09 23:54:23
# Alert: Sensor S2 at Living_Room detected movement. High risk of intrusion. timestamp: 2026-07-09 23:54:23
# Alert: Sensor S3 at Living_Room has triggered a low temperature alert! Current value: 30.8 °F, Frozen pipe risk. timestamp: 2026-07-09 23:54:23
#
# Current Sensor Readings:
# --------------------------------------------------
# Sensor ID: S1 | Type: door | Location: Front_Door | Value: True
# Sensor ID: S2 | Type: motion | Location: Living_Room | Value: True
# Sensor ID: S3 | Type: temperature | Location: Living_Room | Value: 30.8
# Sensor ID: S4 | Type: smoke | Location: Living_Room | Value: False
#
# New Alerts:
# --------------------------------------------------
# [2026-07-09 23:54:23] SECURITY - Opened door (Sensor S1, Severity: HIGH, Value: True)
# [2026-07-09 23:54:23] SECURITY - Motion detected (Sensor S2, Severity: HIGH, Value: True)
# [2026-07-09 23:54:23] SAFETY - Low temperature (Sensor S3, Severity: MEDIUM, Value: 30.8)
#
# System mode changed to HOME
#
# Simulation Cycle #4
# ==================================================
# Alert: Sensor S3 at Living_Room has triggered a low temperature alert! Current value: 30.5 °F, Frozen pipe risk. timestamp: 2026-07-09 23:54:55
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-09 23:54:55
#
# Current Sensor Readings:
# --------------------------------------------------
# Sensor ID: S1 | Type: door | Location: Front_Door | Value: True
# Sensor ID: S2 | Type: motion | Location: Living_Room | Value: True
# Sensor ID: S3 | Type: temperature | Location: Living_Room | Value: 30.5
# Sensor ID: S4 | Type: smoke | Location: Living_Room | Value: True
#
# New Alerts:
# --------------------------------------------------
# [2026-07-09 23:54:55] SAFETY - Low temperature (Sensor S3, Severity: MEDIUM, Value: 30.5)
# [2026-07-09 23:54:55] SAFETY - Smoke detected (Sensor S4, Severity: HIGH, Value: True)
#
# Simulation Cycle #5
# ==================================================
# Alert: Sensor S3 at Living_Room has triggered a high temperature alert! Current value: 95.3 °F, Equipment failure risk. timestamp: 2026-07-09 23:55:28
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-09 23:55:28
#
# Current Sensor Readings:
# --------------------------------------------------
# Sensor ID: S1 | Type: door | Location: Front_Door | Value: True
# Sensor ID: S2 | Type: motion | Location: Living_Room | Value: True
# Sensor ID: S3 | Type: temperature | Location: Living_Room | Value: 95.3
# Sensor ID: S4 | Type: smoke | Location: Living_Room | Value: True
#
# New Alerts:
# --------------------------------------------------
# [2026-07-09 23:55:28] SAFETY - High temperature (Sensor S3, Severity: MEDIUM, Value: 95.3)
# [2026-07-09 23:55:28] SAFETY - Smoke detected (Sensor S4, Severity: HIGH, Value: True)
#
# Simulator stopped.
#
# Final Event Log:
# --------------------------------------------------
# 2026-07-09 23:50:56 - System mode set to AWAY
# 2026-07-09 23:50:56 - Sensor S1 at Front_Door generated reading: False
# 2026-07-09 23:50:56 - Checking sensor S1 at Front_Door
# 2026-07-09 23:50:56 - Sensor S2 at Living_Room generated reading: True
# 2026-07-09 23:50:56 - Checking sensor S2 at Living_Room
# 2026-07-09 23:50:56 - Sensor S3 at Living_Room generated reading: 88.3
# 2026-07-09 23:50:56 - Checking sensor S3 at Living_Room
# 2026-07-09 23:50:56 - Sensor S4 at Living_Room generated reading: True
# 2026-07-09 23:50:56 - Checking sensor S4 at Living_Room
# 2026-07-09 23:52:10 - Sensor S1 at Front_Door generated reading: True
# 2026-07-09 23:52:10 - Checking sensor S1 at Front_Door
# 2026-07-09 23:52:10 - Sensor S2 at Living_Room generated reading: True
# 2026-07-09 23:52:10 - Checking sensor S2 at Living_Room
# 2026-07-09 23:52:10 - Sensor S3 at Living_Room generated reading: 96.2
# 2026-07-09 23:52:10 - Checking sensor S3 at Living_Room
# 2026-07-09 23:52:10 - Sensor S4 at Living_Room generated reading: True
# 2026-07-09 23:52:10 - Checking sensor S4 at Living_Room
# 2026-07-09 23:54:23 - Sensor S1 at Front_Door generated reading: True
# 2026-07-09 23:54:23 - Checking sensor S1 at Front_Door
# 2026-07-09 23:54:23 - Sensor S2 at Living_Room generated reading: True
# 2026-07-09 23:54:23 - Checking sensor S2 at Living_Room
# 2026-07-09 23:54:23 - Sensor S3 at Living_Room generated reading: 30.8
# 2026-07-09 23:54:23 - Checking sensor S3 at Living_Room
# 2026-07-09 23:54:23 - Sensor S4 at Living_Room generated reading: False
# 2026-07-09 23:54:23 - Checking sensor S4 at Living_Room
# 2026-07-09 23:54:55 - System mode changed to HOME
# 2026-07-09 23:54:55 - Sensor S1 at Front_Door generated reading: True
# 2026-07-09 23:54:55 - Checking sensor S1 at Front_Door
# 2026-07-09 23:54:55 - Sensor S2 at Living_Room generated reading: True
# 2026-07-09 23:54:55 - Sensor S3 at Living_Room generated reading: 30.5
# 2026-07-09 23:54:55 - Checking sensor S3 at Living_Room
# 2026-07-09 23:54:55 - Sensor S4 at Living_Room generated reading: True
# 2026-07-09 23:54:55 - Checking sensor S4 at Living_Room
# 2026-07-09 23:55:28 - Sensor S1 at Front_Door generated reading: True
# 2026-07-09 23:55:28 - Checking sensor S1 at Front_Door
# 2026-07-09 23:55:28 - Sensor S2 at Living_Room generated reading: True
# 2026-07-09 23:55:28 - Sensor S3 at Living_Room generated reading: 95.3
# 2026-07-09 23:55:28 - Checking sensor S3 at Living_Room
# 2026-07-09 23:55:28 - Sensor S4 at Living_Room generated reading: True
# 2026-07-09 23:55:28 - Checking sensor S4 at Living_Room

# %% [markdown]
# Step 7: Testing Your System
# Do: Verify your system works correctly and handles all scenarios.

# %%
def format_reading(sensor):
    sensor_type = sensor.type.lower()

    if sensor_type == "motion":
        status = "Motion detected" if sensor.current_value else "No activity"
        return f"[READING] {sensor.location.replace('_', ' ')} Motion: {status}"

    elif sensor_type == "door":
        status = "OPENED" if sensor.current_value else "CLOSED"
        return f"[READING] {sensor.location.replace('_', ' ')}: {status}"

    elif sensor_type == "temperature":
        if sensor.current_value < 35:
            status = "Low"
        elif sensor.current_value > 95:
            status = "High"
        elif sensor.current_value < 65 or sensor.current_value > 75:
            status = "Comfort warning"
        else:
            status = "Normal"

        return f"[READING] {sensor.location.replace('_', ' ')} Temperature: {sensor.current_value}°F ({status})"

    elif sensor_type == "smoke":
        status = "SMOKE DETECTED" if sensor.current_value else "CLEAR"
        return f"[READING] {sensor.location.replace('_', ' ')} Smoke: {status}"

    return f"[READING] {sensor.location.replace('_', ' ')}: {sensor.current_value}"

# %%
def format_alert(alert, sensor, system_mode):
    location = sensor.location.replace('_', ' ')
    sensor_type = sensor.type.lower()

    if sensor_type == "door" and system_mode == "AWAY":
        message = f"{location} opened while in AWAY mode!"

    elif sensor_type == "motion" and system_mode == "AWAY":
        message = f"Motion detected in {location} while in AWAY mode!"

    elif sensor_type == "smoke":
        message = f"Smoke detected in {location}!"

    elif sensor_type == "temperature":
        if alert["message"] == "High temperature":
            message = f"{location} temperature is too high!"
        elif alert["message"] == "Low temperature":
            message = f"{location} temperature is too low!"
        elif alert["message"] == "Temperature below comfort range":
            message = f"{location} feels too cold."
        elif alert["message"] == "Temperature above comfort range":
            message = f"{location} feels too warm."
        else:
            message = alert["message"]

    elif sensor_type == "door" and system_mode == "HOME":
        message = f"{location} has been left open too long."

    else:
        message = alert["message"]

    return f"[ALERT!] 🚨 {alert['severity']}: {alert['alert_type']}: {message}"

# %%
import time

def run_simulator_step7():
    system_mode = get_system_mode()
    state = initialize_system_state(system_mode)

    sensors = state["sensors"]
    alerts_list = state["alerts_list"]
    event_log = state["event_log"]

    print("=== HomeGuard Security System ===")

    while True:
        current_time = datetime.datetime.now().strftime("%H:%M:%S")

        print(f"\nTime: {current_time}")
        print(f"Mode: {system_mode}\n")

        old_alert_count = len(alerts_list)

        for sensor in sensors:
            sensor.read()
            print(format_reading(sensor))

            alert = process_sensor_by_mode(sensor, alerts_list, event_log, system_mode)

            if alert:
                print(format_alert(alert, sensor, system_mode))
                print(f"[LOG] [{current_time}] Sending notification to homeowner...")

        user_choice = input("\nPress Enter for next cycle, type CHANGE to switch mode, or STOP to exit: ").upper()

        if user_choice == "STOP":
            print("\nSimulator stopped.")
            break

        elif user_choice == "CHANGE":
            system_mode = get_system_mode()
            print(f"\n[LOG] [{datetime.datetime.now().strftime('%H:%M:%S')}] System mode changed to {system_mode}")

        time.sleep(1)

# %%
run_simulator_step7()
# Out:
# === HomeGuard Security System ===
#
# Time: 00:41:56
# Mode: AWAY
#
# [READING] Front Door: OPENED
# Alert: Sensor S1 at Front_Door indicates a door opening! High risk of intrusion. timestamp: 2026-07-10 00:41:56
# [ALERT!] 🚨 HIGH: SECURITY: Front Door opened while in AWAY mode!
# [LOG] [00:41:56] Sending notification to homeowner...
# [READING] Living Room Motion: Motion detected
# Alert: Sensor S2 at Living_Room detected movement. High risk of intrusion. timestamp: 2026-07-10 00:41:56
# [ALERT!] 🚨 HIGH: SECURITY: Motion detected in Living Room while in AWAY mode!
# [LOG] [00:41:56] Sending notification to homeowner...
# [READING] Living Room Temperature: 55°F (Comfort warning)
# [READING] Living Room Smoke: SMOKE DETECTED
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-10 00:41:56
# [ALERT!] 🚨 HIGH: SAFETY: Smoke detected in Living Room!
# [LOG] [00:41:56] Sending notification to homeowner...
#
# Time: 00:42:04
# Mode: AWAY
#
# [READING] Front Door: OPENED
# Alert: Sensor S1 at Front_Door indicates a door opening! High risk of intrusion. timestamp: 2026-07-10 00:42:04
# [ALERT!] 🚨 HIGH: SECURITY: Front Door opened while in AWAY mode!
# [LOG] [00:42:04] Sending notification to homeowner...
# [READING] Living Room Motion: Motion detected
# Alert: Sensor S2 at Living_Room detected movement. High risk of intrusion. timestamp: 2026-07-10 00:42:04
# [ALERT!] 🚨 HIGH: SECURITY: Motion detected in Living Room while in AWAY mode!
# [LOG] [00:42:04] Sending notification to homeowner...
# [READING] Living Room Temperature: 55°F (Comfort warning)
# [READING] Living Room Smoke: SMOKE DETECTED
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-10 00:42:04
# [ALERT!] 🚨 HIGH: SAFETY: Smoke detected in Living Room!
# [LOG] [00:42:04] Sending notification to homeowner...
#
# [LOG] [00:42:42] System mode changed to HOME
#
# Time: 00:42:43
# Mode: HOME
#
# [READING] Front Door: OPENED
# [READING] Living Room Motion: Motion detected
# [READING] Living Room Temperature: 55°F (Comfort warning)
# Notification: Sensor S3 at Living_Room reports a low comfort temperature. Current value: 55 °F. Home may feel too cold. timestamp: 2026-07-10 00:42:43
# [ALERT!] 🚨 LOW: COMFORT: Living Room feels too cold.
# [LOG] [00:42:43] Sending notification to homeowner...
# [READING] Living Room Smoke: SMOKE DETECTED
# Alert: Sensor S4 at Living_Room detected smoke. High risk of fire. timestamp: 2026-07-10 00:42:43
# [ALERT!] 🚨 HIGH: SAFETY: Smoke detected in Living Room!
# [LOG] [00:42:43] Sending notification to homeowner...
#
# Simulator stopped.
